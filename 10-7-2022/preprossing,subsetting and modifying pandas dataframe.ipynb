# %%
import pandas as pd
import numpy as np
import random

# %%
data=pd.read_csv("big_mart_sales.csv")
data1=pd.read_csv("big_mart_sales.csv")

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8523, step=1)

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %% [markdown]
# # set index

# %%
ran_list=[random.randint(1,8523)for i in range(8523)]
data.index=ran_list
data
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 3211        9.300          Low Fat         0.016047                  Dairy
# 6511        5.920          Regular         0.019278            Soft Drinks
# 1          17.500          Low Fat         0.016760                   Meat
# 6832       19.200          Regular         0.000000  Fruits and Vegetables
# 2346        8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 626         6.865          Low Fat         0.056783            Snack Foods
# 4533        8.380          Regular         0.046982           Baking Goods
# 7294       10.600          Low Fat         0.035186     Health and Hygiene
# 7640        7.210          Regular         0.145221            Snack Foods
# 2238       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
data1.set_index("Outlet_Identifier",drop=True,inplace=True)

# %%
data1
# Out:
#                   Item_Identifier  Item_Weight Item_Fat_Content  \
# Outlet_Identifier
# OUT049                      FDA15        9.300          Low Fat
# OUT018                      DRC01        5.920          Regular
# OUT049                      FDN15       17.500          Low Fat
# OUT010                      FDX07       19.200          Regular
# OUT013                      NCD19        8.930          Low Fat
# ...                           ...          ...              ...
# OUT013                      FDF22        6.865          Low Fat
# OUT045                      FDS36        8.380          Regular
# OUT035                      NCJ29       10.600          Low Fat
# OUT018                      FDN46        7.210          Regular
# OUT046                      DRG01       14.800          Low Fat
#
#                    Item_Visibility              Item_Type  Item_MRP  \
# Outlet_Identifier
# OUT049                    0.016047                  Dairy  249.8092
# ...

# %% [markdown]
# # SUBSET THE DATA

# %%
data1.loc["OUT018"]
# Out:
#                   Item_Identifier  Item_Weight Item_Fat_Content  \
# Outlet_Identifier
# OUT018                      DRC01        5.920          Regular
# OUT018                      FDP36       10.395          Regular
# OUT018                      NCB42       11.800          Low Fat
# OUT018                      NCS17       18.600          Low Fat
# OUT018                      FDP33       18.700          Low Fat
# ...                           ...          ...              ...
# OUT018                      DRF37       17.250          Low Fat
# OUT018                      FDF05       17.500          Low Fat
# OUT018                      FDH24       20.700          Low Fat
# OUT018                      NCJ19       18.600          Low Fat
# OUT018                      FDN46        7.210          Regular
#
#                    Item_Visibility           Item_Type  Item_MRP  \
# Outlet_Identifier
# OUT018                    0.019278         Soft Drinks   48.2692
# ...

# %%
data1.reset_index(inplace=True)

# %%
data1
# Out:
#      Outlet_Identifier Item_Identifier  Item_Weight Item_Fat_Content  \
# 0               OUT049           FDA15        9.300          Low Fat
# 1               OUT018           DRC01        5.920          Regular
# 2               OUT049           FDN15       17.500          Low Fat
# 3               OUT010           FDX07       19.200          Regular
# 4               OUT013           NCD19        8.930          Low Fat
# ...                ...             ...          ...              ...
# 8518            OUT013           FDF22        6.865          Low Fat
# 8519            OUT045           FDS36        8.380          Regular
# 8520            OUT035           NCJ29       10.600          Low Fat
# 8521            OUT018           FDN46        7.210          Regular
# 8522            OUT046           DRG01       14.800          Low Fat
#
#       Item_Visibility              Item_Type  Item_MRP  \
# 0            0.016047                  Dairy  249.8092
# ...

# %% [markdown]
# # position based

# %%
data1.head(10)
# Out:
#   Outlet_Identifier Item_Identifier  Item_Weight Item_Fat_Content  \
# 0            OUT049           FDA15        9.300          Low Fat
# 1            OUT018           DRC01        5.920          Regular
# 2            OUT049           FDN15       17.500          Low Fat
# 3            OUT010           FDX07       19.200          Regular
# 4            OUT013           NCD19        8.930          Low Fat
# 5            OUT018           FDP36       10.395          Regular
# 6            OUT013           FDO10       13.650          Regular
# 7            OUT027           FDP10          NaN          Low Fat
# 8            OUT045           FDH17       16.200          Regular
# 9            OUT017           FDU28       19.200          Regular
#
#    Item_Visibility              Item_Type  Item_MRP  \
# 0         0.016047                  Dairy  249.8092
# 1         0.019278            Soft Drinks   48.2692
# 2         0.016760                   Meat  141.6180
# ...

# %%
data.tail(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8513           FDH31       12.000          Regular         0.020407
# 8514           FDA01       15.000          Regular         0.054489
# 8515           FDH24       20.700          Low Fat         0.021518
# 8516           NCJ19       18.600          Low Fat         0.118661
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8513                Meat   99.9042            OUT035
# 8514              Canned   57.5904            OUT045
# 8515        Baking Goods  157.5288            OUT018
# ...

# %%
data.head(10).tail(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8           FDH17         16.2          Regular         0.016687
# 9           FDU28         19.2          Regular         0.094450
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 8  Frozen Foods   96.9726            OUT045                       2002
# 9  Frozen Foods  187.8214            OUT017                       2007
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 8         NaN               Tier 2  Supermarket Type1          1076.5986
# 9         NaN               Tier 2  Supermarket Type1          4710.5350

# %%
data1[10:15]
# Out:
#    Outlet_Identifier Item_Identifier  Item_Weight Item_Fat_Content  \
# 10            OUT049           FDY07        11.80          Low Fat
# 11            OUT046           FDA03        18.50          Regular
# 12            OUT049           FDX32        15.10          Regular
# 13            OUT046           FDS46        17.60          Regular
# 14            OUT013           FDF32        16.35          Low Fat
#
#     Item_Visibility              Item_Type  Item_MRP  \
# 10         0.000000  Fruits and Vegetables   45.5402
# 11         0.045464                  Dairy  144.1102
# 12         0.100014  Fruits and Vegetables  145.4786
# 13         0.047257            Snack Foods  119.6782
# 14         0.068024  Fruits and Vegetables  196.4426
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 10                       1999      Medium               Tier 1
# 11                       1997       Small               Tier 1
# ...

# %%
data1[10:20:2]
# Out:
#    Outlet_Identifier Item_Identifier  Item_Weight Item_Fat_Content  \
# 10            OUT049           FDY07        11.80          Low Fat
# 12            OUT049           FDX32        15.10          Regular
# 14            OUT013           FDF32        16.35          Low Fat
# 16            OUT018           NCB42        11.80          Low Fat
# 18            OUT027           DRI11          NaN          Low Fat
#
#     Item_Visibility              Item_Type  Item_MRP  \
# 10         0.000000  Fruits and Vegetables   45.5402
# 12         0.100014  Fruits and Vegetables  145.4786
# 14         0.068024  Fruits and Vegetables  196.4426
# 16         0.008596     Health and Hygiene  115.3492
# 18         0.034238            Hard Drinks  113.2834
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 10                       1999      Medium               Tier 1
# 12                       1999      Medium               Tier 1
# ...

# %%
data1.iloc[[1,5,8,10,667]]
# Out:
#     Outlet_Identifier Item_Identifier  Item_Weight Item_Fat_Content  \
# 1              OUT018           DRC01        5.920          Regular
# 5              OUT018           FDP36       10.395          Regular
# 8              OUT045           FDH17       16.200          Regular
# 10             OUT049           FDY07       11.800          Low Fat
# 667            OUT013           FDU11        4.785          Low Fat
#
#      Item_Visibility              Item_Type  Item_MRP  \
# 1           0.019278            Soft Drinks   48.2692
# 5           0.000000           Baking Goods   51.4008
# 8           0.016687           Frozen Foods   96.9726
# 10          0.000000  Fruits and Vegetables   45.5402
# 667         0.092517                 Breads  120.1098
#
#      Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 1                         2009      Medium               Tier 3
# 5                         2009      Medium               Tier 3
# ...

# %%
data.iloc[10:100]
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 10           FDY07        11.80          Low Fat         0.000000
# 11           FDA03        18.50          Regular         0.045464
# 12           FDX32        15.10          Regular         0.100014
# 13           FDS46        17.60          Regular         0.047257
# 14           FDF32        16.35          Low Fat         0.068024
# ..             ...          ...              ...              ...
# 95           FDU04          NaN          Low Fat         0.009715
# 96           FDF41        12.15          Low Fat         0.131384
# 97           FDB56         8.75          Regular         0.074613
# 98           NCP18          NaN          Low Fat         0.028460
# 99           FDB56         8.75          Regular         0.074627
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 10  Fruits and Vegetables   45.5402            OUT049
# 11                  Dairy  144.1102            OUT046
# ...

# %% [markdown]
# # label Based

# %%
data.loc[20:30]
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 20           FDN22       18.850          Regular         0.138190
# 21           FDW12          NaN          Regular         0.035400
# 22           NCB30       14.600          Low Fat         0.025698
# 23           FDC37          NaN          Low Fat         0.057557
# 24           FDR28       13.850          Regular         0.025896
# 25           NCD06       13.000          Low Fat         0.099887
# 26           FDV10        7.645          Regular         0.066693
# 27           DRJ59       11.650          low fat         0.019356
# 28           FDE51        5.925          Regular         0.161467
# 29           FDC14          NaN          Regular         0.072222
# 30           FDV38       19.250          Low Fat         0.170349
#
#        Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 20   Snack Foods  250.8724            OUT013                       1987
# ...

# %%
data1.set_index("Item_Identifier",drop=True,inplace=True)

# %%
data1.loc[["FDA15","FDX07"],"Item_Visibility"]
# Out:
# Item_Identifier
# FDA15    0.016047
# FDA15    0.016055
# FDA15    0.016019
# FDA15    0.016088
# FDA15    0.026818
# FDA15    0.016009
# FDA15    0.015945
# FDA15    0.016113
# FDX07    0.000000
# FDX07    0.022914
# FDX07    0.022965
# FDX07    0.000000
# FDX07    0.022954
# FDX07    0.022808
# Name: Item_Visibility, dtype: float64

# %% [markdown]
# # value bases

# %%
data1[data1.Item_Visibility==0.138190]
# Out:
# Empty DataFrame
# Columns: [Item_Identifier, Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales]
# Index: []

# %%
data1.loc[data1.Item_Identifier=="FDN22"]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 20             FDN22        18.85          Regular         0.138190
# 3787           FDN22        18.85          Regular         0.138586
# 5836           FDN22        18.85          Regular         0.138869
# 6782           FDN22        18.85          Regular         0.139088
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 20    Snack Foods  250.8724            OUT013                       1987
# 3787  Snack Foods  252.4724            OUT045                       2002
# 5836  Snack Foods  251.8724            OUT018                       2009
# 6782  Snack Foods  251.7724            OUT017                       2007
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 20          High               Tier 3  Supermarket Type1          3775.0860
# 3787         NaN               Tier 2  Supermarket Type1          3271.7412
# ...

# %%
data1[(data1.Item_Identifier=="FDN22")&(data1.Item_MRP==250.8724)]
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 20           FDN22        18.85          Regular          0.13819
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 20  Snack Foods  250.8724            OUT013                       1987
#
#    Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 20        High               Tier 3  Supermarket Type1           3775.086

# %%
data1[data1.Item_MRP.isin([250.8724,252.4724])]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 20             FDN22        18.85          Regular         0.138190
# 3787           FDN22        18.85          Regular         0.138586
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 20    Snack Foods  250.8724            OUT013                       1987
# 3787  Snack Foods  252.4724            OUT045                       2002
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 20          High               Tier 3  Supermarket Type1          3775.0860
# 3787         NaN               Tier 2  Supermarket Type1          3271.7412

# %%
select_col=["Item_Weight","Item_Type"]
data[select_col]
# Out:
#       Item_Weight              Item_Type
# 0           9.300                  Dairy
# 1           5.920            Soft Drinks
# 2          17.500                   Meat
# 3          19.200  Fruits and Vegetables
# 4           8.930              Household
# ...           ...                    ...
# 8518        6.865            Snack Foods
# 8519        8.380           Baking Goods
# 8520       10.600     Health and Hygiene
# 8521        7.210            Snack Foods
# 8522       14.800            Soft Drinks
#
# [8523 rows x 2 columns]

# %%
data1.select_dtypes("object")["Item_Type"]
# Out:
# 0                       Dairy
# 1                 Soft Drinks
# 2                        Meat
# 3       Fruits and Vegetables
# 4                   Household
#                 ...
# 8518              Snack Foods
# 8519             Baking Goods
# 8520       Health and Hygiene
# 8521              Snack Foods
# 8522              Soft Drinks
# Name: Item_Type, Length: 8523, dtype: object

# %% [markdown]
# # Modifying data

# %%
data1.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data1.loc[data1.Item_Weight.isna()==True]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 18             DRI11          NaN          Low Fat         0.034238
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 29             FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37          NaN          Low Fat         0.043792
# 8487           DRG13          NaN          Low Fat         0.037006
# 8488           NCN14          NaN          Low Fat         0.091473
# 8490           FDU44          NaN          Regular         0.102296
# 8504           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# ...

# %%
data1.notnull().sum()
# Out:
# Item_Identifier              8523
# Item_Weight                  7060
# Item_Fat_Content             8523
# Item_Visibility              8523
# Item_Type                    8523
# Item_MRP                     8523
# Outlet_Identifier            8523
# Outlet_Establishment_Year    8523
# Outlet_Size                  6113
# Outlet_Location_Type         8523
# Outlet_Type                  8523
# Item_Outlet_Sales            8523
# dtype: int64

# %% [markdown]
# # Filling missing values

# %%
data1.loc[(data1.Item_Weight.isna()==True),"Item_Weight"]=data1.Item_Weight.mean()
data1.loc[(data1.Outlet_Size.isna()==True),"Outlet_Size"]="Medium"
data1.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
data1.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data1.loc[(data1.Outlet_Size.isna()==True),"Outlet_Size"]=data1.Outlet_Size.mode()
data1.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
data1.Outlet_Size.mode()
# Out:
# 0    Medium
# dtype: object

# %%
data1.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# # methods for missing values

# %%
#data1.column_name.fillna("value",inplace=True)
#data1.replace(to_replace=np.nan,value=67)
#dropna():-to delete the unwanted columnas or rows
#not null()
#isnull()
#fillna()

# %% [markdown]
# # Data Farmatting

# %%
dict={"Name":["Football","FB","basket ball","bb"],
      "num":[11,9,9,11]
     }
df=pd.DataFrame(dict)
df
# Out:
#           Name  num
# 0     Football   11
# 1           FB    9
# 2  basket ball    9
# 3           bb   11

# %%
mapping={
    "Football":"FB",
    "FB":"FB",
    "basket ball":"bb",
    "bb":"bb"
}

# %%
df.Name=df.Name.map(mapping)
df
# Out:
#   Name  num
# 0   FB   11
# 1   FB    9
# 2   bb    9
# 3   bb   11

# %%
df["number"]=[110,100,120,140]
df
# Out:
#   Name  num  number
# 0   FB   11     110
# 1   FB    9     100
# 2   bb    9     120
# 3   bb   11     140

# %%
df["score"]=df.number.apply(lambda x:x/10)  #create a new column by using existing column
df
# Out:
#   Name  num  number  score
# 0   FB   11     110   11.0
# 1   FB    9     100   10.0
# 2   bb    9     120   12.0
# 3   bb   11     140   14.0
